# %%
import pandas as pd
import ExploratoryDataAnalysis as eda

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
for domain in ['technology', 'health', 'music', 'politics']:
    df = pd.read_pickle(f'pickles/{domain}_tweets_filtered.pkl')
    dirpath = f'figures/eda/{domain}/'
    eda.plot_user_counts_distribution(df, title=domain, path=dirpath+'tweet_count_per_user_dist.png')
    eda.plot_hours_distribution(df, title=domain, path=dirpath+'hour_dist.png')
    eda.plot_days_distribution(df, title=domain, path=dirpath+'day_dist.png')
    eda.plot_days_hours_distribution(df, title=domain, path=dirpath+'day_hour_dist.png')
    eda.plot_scaled_favorite_count(df, title=domain, path=dirpath+'scaled_fav_count_dist.png')
    eda.wordcloud(df, title=domain, path=dirpath+'wordcloud.png')
